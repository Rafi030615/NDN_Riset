# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(1, 6):
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario1\skenario1-1-{i}\log1-1-{i}.csv"
    globals()[f'O11{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario1\skenario1-2-{i}\log1-2-{i}.csv"
    globals()[f'O12{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario1\skenario1-3-{i}\log1-3-{i}.csv"
    globals()[f'O13{i}'] = pd.read_csv(filepath, index_col = False)
    
for i in range(1, 6):
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario1\log1-1-{i}.csv"
    globals()[f'U11{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario1\log1-2-{i}.csv"
    globals()[f'U12{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario1\log1-3-{i}.csv"
    globals()[f'U13{i}'] = pd.read_csv(filepath, index_col = False)

# %%
import matplotlib.pyplot as plt

dfo = [O112, O122, O133]
dfu = [U112, U122, U133]

tinggiu = []
for df in dfu:
    tinggiu.append(df.loc[0]["AverageRTT(ms)"])

tinggio = []
for df in dfo:
    tinggio.append(df.loc[0]["AverageRTT(ms)"])

datar = [1, 2, 3]
plt.figure(figsize=(10, 5))
plt.plot(datar, tinggiu, marker='o', linestyle='-', label='Ubuntu')
plt.plot(datar, tinggio, marker='o', linestyle='-', label='OpenWRT')
plt.ylabel("Average RTT")
plt.title("RTT")
plt.legend()
plt.show()

# %%
for i in range(1, 6):
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario2\skenario2-1-{i}\log2-1-{i}.csv"
    globals()[f'O21{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario2\skenario2-2-{i}\log2-2-{i}.csv"
    globals()[f'O22{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario2\skenario2-3-{i}\log2-3-{i}.csv"
    globals()[f'O23{i}'] = pd.read_csv(filepath, index_col = False)
    
for i in range(1, 6):
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario2\log2-1-{i}.csv"
    globals()[f'U21{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario2\log2-2-{i}.csv"
    globals()[f'U22{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario2\log2-3-{i}.csv"
    globals()[f'U23{i}'] = pd.read_csv(filepath, index_col = False)

# %%
import matplotlib.pyplot as plt

dfo = [O212, O222, O233]
dfu = [U211, U222, U231]

tinggiu = []
for df in dfu:
    tinggiu.append(df.loc[0]["AverageRTT(ms)"])

tinggio = []
for df in dfo:
    tinggio.append(df.loc[0]["AverageRTT(ms)"])

datar = [1, 2, 3]
plt.figure(figsize=(10, 5))
plt.plot(datar, tinggiu, marker='o', linestyle='-', label='Ubuntu')
plt.plot(datar, tinggio, marker='o', linestyle='-', label='OpenWRT')
plt.ylabel("Average RTT")
plt.title("RTT")
plt.legend()
plt.show()

# %%
for i in range(1, 6):
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario3\skenario3-1-{i}\log3-1-{i}.csv"
    globals()[f'O31{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario3\skenario3-2-{i}\log3-2-{i}.csv"
    globals()[f'O32{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Consumer\skenario3\skenario3-3-{i}\log3-3-{i}.csv"
    globals()[f'O33{i}'] = pd.read_csv(filepath, index_col = False)
    
for i in range(1, 6):
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario3\log3-1-{i}.csv"
    globals()[f'U31{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario3\log3-2-{i}.csv"
    globals()[f'U32{i}'] = pd.read_csv(filepath, index_col = False)
    
    filepath = rf"C:\Users\Lenovo\NDN_Riset\Ubuntu\Data\skenario3\log3-3-{i}.csv"
    globals()[f'U33{i}'] = pd.read_csv(filepath, index_col = False)

# %%
import matplotlib.pyplot as plt

dfo = [O311, O324, O333]
dfu = [U312, U322, U332]

tinggiu = []
for df in dfu:
    tinggiu.append(df.loc[0]["AverageRTT(ms)"])

tinggio = []
for df in dfo:
    tinggio.append(df.loc[0]["AverageRTT(ms)"])

datar = [1, 2, 3]
plt.figure(figsize=(10, 5))
plt.plot(datar, tinggiu, marker='o', linestyle='-', label='Ubuntu')
plt.plot(datar, tinggio, marker='o', linestyle='-', label='OpenWRT')
plt.ylabel("Average RTT")
plt.title("RTT")
plt.legend()
plt.show()
